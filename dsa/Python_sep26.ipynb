# %%
array = [10,20,30,40,50]

# %%
array[2]
# Out:
# 30

# %%
array.insert(2,35)


array
# Out:
# [10, 20, 35, 30, 40, 50]

# %%
array.append(56)

# %%
array.pop(4)
array.remove(20)

array
# Out:
# [10, 35, 30, 56]
